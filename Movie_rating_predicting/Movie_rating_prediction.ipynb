# %% [markdown]
# # BlESMAN NEWTON

# %% [markdown]
# ### Movie Rating Prediction using Python

# %%
# Importing libs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
# loading Dataset

# %%
movie_data = pd.read_csv('IMDb-Movies-India.csv', encoding='latin-1' )

# %%
# check the first 10 rows

# %%
movie_data['Duration'] = movie_data['Duration'].str.rstrip('min')

# %%
movie_data['Name'] = movie_data['Name'].str.strip('123.#?:=*!"£$%^&@~;')
movie_data
# Out:
#                                     Name    Year Duration            Genre  \
# 0                                            NaN      NaN            Drama
# 1      Gadhvi (He thought he was Gandhi) -2019.0    109              Drama
# 2                             Homecoming -2021.0      90    Drama, Musical
# 3                                 Yaaram -2019.0     110   Comedy, Romance
# 4                         And Once Again -2010.0     105             Drama
# ...                                  ...     ...      ...              ...
# 15504                Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                              Zulmi -1999.0     129     Action, Drama
# 15506                          Zulmi Raj -2005.0      NaN           Action
# 15507                      Zulmi Shikari -1988.0      NaN           Action
# 15508                       Zulm-O-Sitam -1998.0     130     Action, Drama
#
# ...

# %%
movie_data.head(10)
# Out:
#                                 Name    Year Duration  \
# 0                                        NaN      NaN
# 1  Gadhvi (He thought he was Gandhi) -2019.0    109
# 2                         Homecoming -2021.0      90
# 3                             Yaaram -2019.0     110
# 4                     And Once Again -2010.0     105
# 5                  Aur Pyaar Ho Gaya -1997.0     147
# 6                             Yahaan -2005.0     142
# 7                      in for Motion -2008.0      59
# 8                    A Question Mark -2012.0      82
# 9                            Andheri -2014.0     116
#
#                        Genre  Rating Votes            Director  \
# 0                      Drama     NaN   NaN       J.S. Randhawa
# 1                      Drama     7.0     8       Gaurav Bakshi
# 2             Drama, Musical     NaN   NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4    35          Ovais Khan
# ...

# %%
# check the last 10 rows

# %%
movie_data.tail(10)
# Out:
#                       Name    Year Duration                 Genre  Rating  \
# 15499        Zulm Ka Jawab -1995.0      NaN                Action     NaN
# 15500      Zulm Ka Muqabla -1993.0      NaN                Action     NaN
# 15501      Zulm Ki Hukumat -1992.0      NaN  Action, Crime, Drama     5.3
# 15502        Zulm Ki Pukar -1979.0      NaN                Action     NaN
# 15503      Zulm Ki Zanjeer -1989.0     125   Action, Crime, Drama     5.8
# 15504  Zulm Ko Jala Doonga -1988.0      NaN                Action     4.6
# 15505                Zulmi -1999.0     129          Action, Drama     4.5
# 15506            Zulmi Raj -2005.0      NaN                Action     NaN
# 15507        Zulmi Shikari -1988.0      NaN                Action     NaN
# 15508         Zulm-O-Sitam -1998.0     130          Action, Drama     6.2
#
#       Votes           Director                Actor 1              Actor 2  \
# 15499   NaN    Surinder Kapoor            Goga Kapoor        Shakti Kapoor
# ...

# %%
# display the shape of the dataset (Rows, Columns)

# %%
movie_data.shape
# Out:
# (15509, 10)

# %%
print('Number of Rows:', movie_data.shape[0])
print('Number of Columns:', movie_data.shape[1])
# Out:
# Number of Rows: 15509
# Number of Columns: 10

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
movie_data.duplicated().any()
# Out:
# True

# %%
movie_data = movie_data.drop_duplicates()

# %%
movie_data.duplicated().any()
# Out:
# False

# %%
movie_data
# Out:
#                                     Name    Year Duration            Genre  \
# 0                                            NaN      NaN            Drama
# 1      Gadhvi (He thought he was Gandhi) -2019.0    109              Drama
# 2                             Homecoming -2021.0      90    Drama, Musical
# 3                                 Yaaram -2019.0     110   Comedy, Romance
# 4                         And Once Again -2010.0     105             Drama
# ...                                  ...     ...      ...              ...
# 15504                Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                              Zulmi -1999.0     129     Action, Drama
# 15506                          Zulmi Raj -2005.0      NaN           Action
# 15507                      Zulmi Shikari -1988.0      NaN           Action
# 15508                       Zulm-O-Sitam -1998.0     130     Action, Drama
#
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15502 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15502 non-null  object
#  1   Year      14976 non-null  float64
#  2   Duration  7239 non-null   object
#  3   Genre     13626 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14978 non-null  object
#  7   Actor 1   13887 non-null  object
#  8   Actor 2   13122 non-null  object
#  9   Actor 3   12363 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.3+ MB

# %%
movie_data.isnull()
# Out:
#         Name   Year  Duration  Genre  Rating  Votes  Director  Actor 1  \
# 0      False   True      True  False    True   True     False    False
# 1      False  False     False  False   False  False     False    False
# 2      False  False     False  False    True   True     False    False
# 3      False  False     False  False   False  False     False    False
# 4      False  False     False  False    True   True     False    False
# ...      ...    ...       ...    ...     ...    ...       ...      ...
# 15504  False  False      True  False   False  False     False    False
# 15505  False  False     False  False   False  False     False    False
# 15506  False  False      True  False    True   True     False    False
# 15507  False  False      True  False    True   True      True     True
# 15508  False  False     False  False   False  False     False    False
#
#        Actor 2  Actor 3
# 0        False    False
# 1        False    False
# 2        False    False
# ...

# %%
movie_data.isnull().values.any()
# Out:
# True

# %%
movie_data.isnull().sum()
# Out:
# Name           0
# Year         526
# Duration    8263
# Genre       1876
# Rating      7583
# Votes       7582
# Director     524
# Actor 1     1615
# Actor 2     2380
# Actor 3     3139
# dtype: int64

# %%
sns.heatmap(movie_data.isnull(), cmap="YlGnBu")
# Out:
# <Axes: >

# %%
missing_per = movie_data.isnull().sum() * len(movie_data) / 100
missing_per.sum()
# Out:
# 5191309.76

# %%
movie_data = movie_data.dropna(axis=0)

# %%
movie_data
# Out:
#                                     Name    Year Duration  \
# 1      Gadhvi (He thought he was Gandhi) -2019.0    109
# 3                                 Yaaram -2019.0     110
# 5                      Aur Pyaar Ho Gaya -1997.0     147
# 6                                 Yahaan -2005.0     142
# 8                        A Question Mark -2012.0      82
# ...                                  ...     ...      ...
# 15493                             Zubaan -2015.0     115
# 15494                           Zubeidaa -2001.0     153
# 15503                    Zulm Ki Zanjeer -1989.0     125
# 15505                              Zulmi -1999.0     129
# 15508                       Zulm-O-Sitam -1998.0     130
#
#                            Genre  Rating Votes         Director  \
# 1                          Drama     7.0     8    Gaurav Bakshi
# 3                Comedy, Romance     4.4    35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7   827     Rahul Rawail
# ...

# %%
movie_data.describe()
# Out:
#               Year       Rating
# count  5659.000000  5659.000000
# mean  -1996.247570     5.898533
# std      19.741839     1.381165
# min   -2021.000000     1.100000
# 25%   -2013.000000     5.000000
# 50%   -2002.000000     6.100000
# 75%   -1983.000000     6.900000
# max   -1931.000000    10.000000

# %%
movie_data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
movie_data['Duration'] = pd.to_numeric(movie_data['Duration'], errors='coerce')
new_data = movie_data[movie_data['Duration']>= 180] ['Name']
new_data
# Out:
# C:\Users\Goodness\AppData\Local\Temp\ipykernel_16820\134995135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data['Duration'] = pd.to_numeric(movie_data['Duration'], errors='coerce')
# 63            rd March 1931: Shaheed
# 239                      Aag Ka Gola
# 441      Aap Mujhe Achche Lagne Lage
# 451                      Aar Ya Paar
# 490      Aasma: The Sky Is the Limit
#                     ...
# 14955                       Wafadaar
# 14968                         Wajood
# 15051            What's Your Raashee
# 15054                When Love Calls
# 15178                        Yalgaar
# Name: Name, Length: 156, dtype: object

# %%
movie_data
# Out:
#                                     Name    Year  Duration  \
# 1      Gadhvi (He thought he was Gandhi) -2019.0       109
# 3                                 Yaaram -2019.0       110
# 5                      Aur Pyaar Ho Gaya -1997.0       147
# 6                                 Yahaan -2005.0       142
# 8                        A Question Mark -2012.0        82
# ...                                  ...     ...       ...
# 15493                             Zubaan -2015.0       115
# 15494                           Zubeidaa -2001.0       153
# 15503                    Zulm Ki Zanjeer -1989.0       125
# 15505                              Zulmi -1999.0       129
# 15508                       Zulm-O-Sitam -1998.0       130
#
#                            Genre  Rating Votes         Director  \
# 1                          Drama     7.0     8    Gaurav Bakshi
# 3                Comedy, Romance     4.4    35       Ovais Khan
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5659 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5659 non-null   object
#  1   Year      5659 non-null   float64
#  2   Duration  5659 non-null   int64
#  3   Genre     5659 non-null   object
#  4   Rating    5659 non-null   float64
#  5   Votes     5659 non-null   object
#  6   Director  5659 non-null   object
#  7   Actor 1   5659 non-null   object
#  8   Actor 2   5659 non-null   object
#  9   Actor 3   5659 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 486.3+ KB

# %%
movie_data
# Out:
#                                     Name    Year  Duration  \
# 1      Gadhvi (He thought he was Gandhi) -2019.0       109
# 3                                 Yaaram -2019.0       110
# 5                      Aur Pyaar Ho Gaya -1997.0       147
# 6                                 Yahaan -2005.0       142
# 8                        A Question Mark -2012.0        82
# ...                                  ...     ...       ...
# 15493                             Zubaan -2015.0       115
# 15494                           Zubeidaa -2001.0       153
# 15503                    Zulm Ki Zanjeer -1989.0       125
# 15505                              Zulmi -1999.0       129
# 15508                       Zulm-O-Sitam -1998.0       130
#
#                            Genre  Rating Votes         Director  \
# 1                          Drama     7.0     8    Gaurav Bakshi
# 3                Comedy, Romance     4.4    35       Ovais Khan
# ...

# %%
movie_data.isnull().values.any()
# Out:
# False

# %%
movie_data.loc[:, 'Votes'] = pd.to_numeric(movie_data['Votes'], errors='coerce')
movie_data['Votes'].mean()
# Out:
# 2697.649584732285

# %%
movie_data.loc[:, 'Votes'] = pd.to_numeric(movie_data['Votes'], errors='coerce')
movie_data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# -2012.0    9900.971429
# -2007.0    7212.017094
# -2016.0    6780.601156
# -2009.0    5938.805085
# -2020.0    5819.257143
#               ...
# -1933.0           12.0
# -1932.0           12.0
# -1938.0           10.6
# -1939.0            9.5
# -1934.0            8.5
# Name: Votes, Length: 91, dtype: object

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Year', y='Votes', data=movie_data)
plt.title('Votes by Year')
plt.show()

# %%
top_ten_rating = movie_data.nlargest(10, 'Duration')[['Name', 'Duration']].set_index('Name')
top_ten_rating
# Out:
#                                     Duration
# Name
# Gangs of Wasseypur                       321
# Athidhi                                  300
# LOC: Kargil                              255
# Vidhyaarthi: The Power of Students       250
# Janwar                                   247
# Aasma: The Sky Is the Limit              240
# Veera                                    240
# Vivekananda                              240
# Sangam                                   238
# Taj Mahal: A Monument of Love            235

# %%
sns.barplot(x='Duration', y=top_ten_rating.index, data=top_ten_rating )
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Name', y='Rating', data=movie_data.head(70), color='r')
plt.xticks(rotation=90)
plt.title('Rating of movie')
plt.xlabel('Movie Name')
plt.ylabel('Rating')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Director', y='Votes', data=movie_data.head(100), color='g')
plt.xticks(rotation=90)
plt.title('Votes per Director')
plt.xlabel('Director Name')
plt.ylabel('Votes')
plt.show()
# Out:
# C:\Users\Goodness\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Goodness\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(data=movie_data)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Goodness\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Goodness\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Goodness\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.distplot(movie_data['Rating'], color='b')
plt.title('Rating Density')
plt.show()
# Out:
# C:\Users\Goodness\AppData\Local\Temp\ipykernel_16820\2428652173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(movie_data['Rating'], color='b')
# C:\Users\Goodness\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
X = movie_data[['Genre', 'Duration', 'Votes', 'Year']]
y = movie_data['Rating']
#X = X.reshape(1,-1)

# %%
y = pd.cut(y, bins=2, labels=[0,1])
#print(y.dtype)

# %%
# Handling categorical features and scaling numerical features
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['Duration', 'Votes','Year']),
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['Genre'])
    ]
)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression()),
])

# %%
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Duration', 'Votes',
#                                                    'Year']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Genre'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.21155340733152167
# R-squared: 0.10030263170272713

# %%
y_pred
# Out:
# array([0.68186353, 0.48290091, 0.60601982, ..., 0.65751167, 1.09533627,
#        0.83665454])

# %%
movie_data.isnull().values.any()
# Out:
# False

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor()),
])

# %%
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Duration', 'Votes',
#                                                    'Year']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Genre'])])),
#                 ('regressor', RandomForestRegressor())])

# %%
from sklearn.model_selection import GridSearchCV


param_grid = [
    {'regressor__n_estimators': [10, 100, 200, 300], 'regressor__max_depth': [None, 5, 10], 'regressor__min_samples_split': [2,3,4]}
]
grid_search = GridSearchCV(pipeline, param_grid, cv=3, scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(X_train, Y_train)

# %%
# Evaluate the best model
best_model = grid_search.best_estimator_
y_pred_rf = best_model.predict(X_test)

# %%
mse_rf = mean_squared_error(Y_test, y_pred_rf)
r2_rf = r2_score(Y_test, y_pred_rf)

# %%
print(f'Random Forest - Mean Squared Error: {mse_rf}')
print(f'Random Forest - R-squared: {r2_rf}')
